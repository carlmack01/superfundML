# %% [markdown]
# # Data Cleaning for Project 3: Superfund Site Data

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import os
import json

# %% [markdown]
# ### Set File Locations

# %%
# note that some of the raw data files are very large
# these very large files are located in a gitignored directory.

# raw data files
raw_data_file = "../00_Data/raw_data/priorities_list_full.json"

# clean data files
cleaned_data_csv = "../00_Data/cleaned_data/cleaned_priorities_list.csv"
cleaned_data_json = "../00_Data/cleaned_data/cleaned_priorities_list.json"

# %% [markdown]
# ## Exploring the Dataset

# %% [markdown]
# ### Bring in the tract data

# %%
data_df = pd.read_json(raw_data_file)

# %% [markdown]
# ### Take a look at the site data
# Some things to note here:
# 1. There are 1344 records and 359 columns.
# 2. There are plenty of nulls about.
# 3. Financial values, e.g. 'Med_House_Value_BG_ACS_09_13', are stored as strings.

# %%
data_df.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1344 entries, 0 to 1343
# Data columns (total 359 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   FIPS_Full                         1344 non-null   int64
#  1   address                           1344 non-null   object
#  2   city                              1344 non-null   object
#  3   date_added                        1344 non-null   object
#  4   federal_facility_ind              1344 non-null   object
#  5   federal_register_url              1344 non-null   object
#  6   geocode_source                    1344 non-null   object
#  7   latitude                          1339 non-null   float64
#  8   longitude                         1339 non-null   float64
#  9   site_epa_id                       1344 non-null   object
#  10  site_name                         1344 non-null   object
#  11  site_narrative_url                1342 non-null   object
#  12  site_progress_url                 1344 non-null   object
#  13  site_score                        1309 non-null   float64
#  14  text                              1342 non-null   object
#  15  FIPS_Block_Group                  1344 non-null   int64
#  16  State                             1336 non-null   float64
#  17  State_name                        1336 non-null   object
#  18  County                            1336 non-null   float64
#  19  County_name                       1336 non-null   object
#  20  Tract                             1336 non-null   float64
#  21  Block_Group                       1336 non-null   float64
#  22  Flag                              0 non-null      float64
#  23  LAND_AREA                         1334 non-null   float64
#  24  AIAN_LAND                         1334 non-null   float64
#  25  URBANIZED_AREA_POP_CEN_2010       1334 non-null   float64
#  26  URBAN_CLUSTER_POP_CEN_2010        1334 non-null   float64
#  27  RURAL_POP_CEN_2010                1334 non-null   float64
#  28  Tot_Population_CEN_2010           1334 non-null   float64
#  29  Tot_Population_ACS_09_13          1334 non-null   float64
#  30  Tot_Population_ACSMOE_09_13       1334 non-null   float64
#  31  Males_CEN_2010                    1334 non-null   float64
#  32  Males_ACS_09_13                   1334 non-null   float64
#  33  Males_ACSMOE_09_13                1334 non-null   float64
#  34  Females_CEN_2010                  1334 non-null   float64
#  35  Females_ACS_09_13                 1334 non-null   float64
#  36  Females_ACSMOE_09_13              1334 non-null   float64
#  37  Pop_under_5_CEN_2010              1334 non-null   float64
#  38  Pop_under_5_ACS_09_13             1334 non-null   float64
#  39  Pop_under_5_ACSMOE_09_13          1334 non-null   float64
#  40  Pop_5_17_CEN_2010                 1334 non-null   float64
#  41  Pop_5_17_ACS_09_13                1334 non-null   float64
#  42  Pop_5_17_ACSMOE_09_13             1334 non-null   float64
#  43  Pop_18_24_CEN_2010                1334 non-null   float64
#  44  Pop_18_24_ACS_09_13               1334 non-null   float64
#  45  Pop_18_24_ACSMOE_09_13            1334 non-null   float64
#  93  One_Health_Ins_ACS_09_13          1334 non-null   float64
#  94  One_Health_Ins_ACSMOE_09_13       1334 non-null   float64
#  95  Two_Plus_Health_Ins_ACS_09_13     1334 non-null   float64
#  96  Two_Plus_Health_Ins_ACSMOE_09_13  1334 non-null   float64
#  97  No_Health_Ins_ACS_09_13           1334 non-null   float64
#  98  No_Health_Ins_ACSMOE_09_13        1334 non-null   float64
#  99  Pop_1yr_Over_ACS_09_13            1334 non-null   float64
#  100 Pop_1yr_Over_ACSMOE_09_13         1334 non-null   float64
#  101 Diff_HU_1yr_Ago_ACS_09_13         1334 non-null   float64
#  102 Diff_HU_1yr_Ago_ACSMOE_09_13      1334 non-null   float64
#  103 ENG_VW_SPAN_ACS_09_13             1334 non-null   float64
#  104 ENG_VW_SPAN_ACSMOE_09_13          1334 non-null   float64
#  105 ENG_VW_INDO_EURO_ACS_09_13        1334 non-null   float64
#  106 ENG_VW_INDO_EURO_ACSMOE_09_13     1334 non-null   float64
#  107 ENG_VW_API_ACS_09_13              1334 non-null   float64
#  108 ENG_VW_API_ACSMOE_09_13           1334 non-null   float64
#  109 ENG_VW_OTHER_ACS_09_13            1334 non-null   float64
#  110 ENG_VW_OTHER_ACSMOE_09_13         1334 non-null   float64
#  111 ENG_VW_ACS_09_13                  1334 non-null   float64
#  112 ENG_VW_ACSMOE_09_13               1334 non-null   float64
#  113 Rel_Family_HHDS_CEN_2010          1334 non-null   float64
#  114 Rel_Family_HHD_ACS_09_13          1334 non-null   float64
#  115 Rel_Family_HHD_ACSMOE_09_13       1334 non-null   float64
#  116 MrdCple_Fmly_HHD_CEN_2010         1334 non-null   float64
#  117 MrdCple_Fmly_HHD_ACS_09_13        1334 non-null   float64
#  118 MrdCple_Fmly_HHD_ACSMOE_09_13     1334 non-null   float64
#  119 Not_MrdCple_HHD_CEN_2010          1334 non-null   float64
#  120 Not_MrdCple_HHD_ACS_09_13         1334 non-null   float64
#  121 Not_MrdCple_HHD_ACSMOE_09_13      1334 non-null   float64
#  122 Female_No_HB_CEN_2010             1334 non-null   float64
#  123 Female_No_HB_ACS_09_13            1334 non-null   float64
#  124 Female_No_HB_ACSMOE_09_13         1334 non-null   float64
#  125 NonFamily_HHD_CEN_2010            1334 non-null   float64
#  126 NonFamily_HHD_ACS_09_13           1334 non-null   float64
#  127 NonFamily_HHD_ACSMOE_09_13        1334 non-null   float64
#  128 Sngl_Prns_HHD_CEN_2010            1334 non-null   float64
#  129 Sngl_Prns_HHD_ACS_09_13           1334 non-null   float64
#  130 Sngl_Prns_HHD_ACSMOE_09_13        1334 non-null   float64
#  131 HHD_PPL_Und_18_CEN_2010           1334 non-null   float64
#  132 HHD_PPL_Und_18_ACS_09_13          1334 non-null   float64
#  133 HHD_PPL_Und_18_ACSMOE_09_13       1334 non-null   float64
#  134 Tot_Prns_in_HHD_CEN_2010          1334 non-null   float64
#  135 Tot_Prns_in_HHD_ACS_09_13         1334 non-null   float64
#  136 Tot_Prns_in_HHD_ACSMOE_09_13      1334 non-null   float64
#  137 Rel_Child_Under_6_CEN_2010        1334 non-null   float64
#  138 Rel_Child_Under_6_ACS_09_13       1334 non-null   float64
#  139 Rel_Child_Under_6_ACSMOE_09_13    1334 non-null   float64
#  140 HHD_Moved_in_ACS_09_13            1334 non-null   float64
#  141 HHD_Moved_in_ACSMOE_09_13         1334 non-null   float64
#  142 PUB_ASST_INC_ACS_09_13            1334 non-null   float64
#  143 PUB_ASST_INC_ACSMOE_09_13         1334 non-null   float64
#  144 Med_HHD_Inc_BG_ACS_09_13          1311 non-null   object
#  145 Med_HHD_Inc_BG_ACSMOE_09_13       1310 non-null   object
#  146 Med_HHD_Inc_TR_ACS_09_13          1327 non-null   object
#  147 Med_HHD_Inc_TR_ACSMOE_09_13       1326 non-null   object
#  148 Aggregate_HH_INC_ACS_09_13        1311 non-null   object
#  149 Aggregate_HH_INC_ACSMOE_09_13     1311 non-null   object
#  150 Tot_Housing_Units_CEN_2010        1334 non-null   float64
#  151 Tot_Housing_Units_ACS_09_13       1334 non-null   float64
#  152 Tot_Housing_Units_ACSMOE_09_13    1334 non-null   float64
#  153 Tot_Occp_Units_CEN_2010           1334 non-null   float64
#  154 Tot_Occp_Units_ACS_09_13          1334 non-null   float64
#  155 Tot_Occp_Units_ACSMOE_09_13       1334 non-null   float64
#  156 Tot_Vacant_Units_CEN_2010         1334 non-null   float64
#  157 Tot_Vacant_Units_ACS_09_13        1334 non-null   float64
#  158 Tot_Vacant_Units_ACSMOE_09_13     1334 non-null   float64
#  159 Renter_Occp_HU_CEN_2010           1334 non-null   float64
#  160 Renter_Occp_HU_ACS_09_13          1334 non-null   float64
#  161 Renter_Occp_HU_ACSMOE_09_13       1334 non-null   float64
#  162 Owner_Occp_HU_CEN_2010            1334 non-null   float64
#  163 Owner_Occp_HU_ACS_09_13           1334 non-null   float64
#  164 Owner_Occp_HU_ACSMOE_09_13        1334 non-null   float64
#  165 Single_Unit_ACS_09_13             1334 non-null   float64
#  166 Single_Unit_ACSMOE_09_13          1334 non-null   float64
#  167 MLT_U2_9_STRC_ACS_09_13           1334 non-null   float64
#  168 MLT_U2_9_STRC_ACSMOE_09_13        1334 non-null   float64
#  169 MLT_U10p_ACS_09_13                1334 non-null   float64
#  170 MLT_U10p_ACSMOE_09_13             1334 non-null   float64
#  171 Mobile_Homes_ACS_09_13            1334 non-null   float64
#  172 Mobile_Homes_ACSMOE_09_13         1334 non-null   float64
#  173 Crowd_Occp_U_ACS_09_13            1334 non-null   float64
#  174 Crowd_Occp_U_ACSMOE_09_13         1334 non-null   float64
#  175 Occp_U_NO_PH_SRVC_ACS_09_13       1334 non-null   float64
#  176 Occp_U_NO_PH_SRVC_ACSMOE_09_13    1334 non-null   float64
#  177 No_Plumb_ACS_09_13                1321 non-null   float64
#  178 No_Plumb_ACSMOE_09_13             1321 non-null   float64
#  179 Recent_Built_HU_ACS_09_13         1334 non-null   float64
#  180 Recent_Built_HU_ACSMOE_09_13      1334 non-null   float64
#  181 Med_House_Value_BG_ACS_09_13      1245 non-null   object
#  272 pct_Pop_1yr_Over_ACS_09_13        1324 non-null   float64
#  273 pct_Pop_1yr_Over_ACSMOE_09_13     1324 non-null   float64
#  274 pct_Diff_HU_1yr_Ago_ACS_09_13     1311 non-null   float64
#  275 pct_Diff_HU_1yr_Ago_ACSMOE_09_13  1311 non-null   float64
#  276 pct_ENG_VW_SPAN_ACS_09_13         1317 non-null   float64
#  277 pct_ENG_VW_SPAN_ACSMOE_09_13      1317 non-null   float64
#  278 pct_ENG_VW_INDOEURO_ACS_09_13     1317 non-null   float64
#  279 pct_ENG_VW_INDOEURO_ACSMOE_09_13  1317 non-null   float64
#  280 pct_ENG_VW_API_ACS_09_13          1317 non-null   float64
#  281 pct_ENG_VW_API_ACSMOE_09_13       1317 non-null   float64
#  282 pct_ENG_VW_OTHER_ACS_09_13        1317 non-null   float64
#  283 pct_ENG_VW_OTHER_ACSMOE_09_13     1317 non-null   float64
#  284 pct_ENG_VW_ACS_09_13              1317 non-null   float64
#  285 pct_ENG_VW_ACSMOE_09_13           1317 non-null   float64
#  286 pct_Rel_Family_HHDS_CEN_2010      1327 non-null   float64
#  287 pct_Rel_Family_HHD_ACS_09_13      1317 non-null   float64
#  288 pct_Rel_Family_HHD_ACSMOE_09_13   1317 non-null   float64
#  289 pct_MrdCple_HHD_CEN_2010          1327 non-null   float64
#  290 pct_MrdCple_HHD_ACS_09_13         1317 non-null   float64
#  291 pct_MrdCple_HHD_ACSMOE_09_13      1317 non-null   float64
#  292 pct_Not_MrdCple_HHD_CEN_2010      1327 non-null   float64
#  293 pct_Not_MrdCple_HHD_ACS_09_13     1317 non-null   float64
#  294 pct_Not_MrdCple_HHD_ACSMOE_09_13  1317 non-null   float64
#  295 pct_Female_No_HB_CEN_2010         1327 non-null   float64
#  296 pct_Female_No_HB_ACS_09_13        1317 non-null   float64
#  297 pct_Female_No_HB_ACSMOE_09_13     1317 non-null   float64
#  298 pct_NonFamily_HHD_CEN_2010        1327 non-null   float64
#  299 pct_NonFamily_HHD_ACS_09_13       1317 non-null   float64
#  300 pct_NonFamily_HHD_ACSMOE_09_13    1317 non-null   float64
#  301 pct_Sngl_Prns_HHD_CEN_2010        1327 non-null   float64
#  302 pct_Sngl_Prns_HHD_ACS_09_13       1317 non-null   float64
#  303 pct_Sngl_Prns_HHD_ACSMOE_09_13    1317 non-null   float64
#  304 pct_HHD_PPL_Und_18_CEN_2010       1327 non-null   float64
#  305 pct_HHD_PPL_Und_18_ACS_09_13      1317 non-null   float64
#  306 pct_HHD_PPL_Und_18_ACSMOE_09_13   1317 non-null   float64
#  307 avg_Tot_Prns_in_HHD_CEN_2010      1327 non-null   float64
#  308 avg_Tot_Prns_in_HHD_ACS_09_13     1317 non-null   float64
#  309 avg_Tot_Prns_in_HHD_ACSMOE_09_13  1317 non-null   float64
#  310 pct_Rel_Under_6_CEN_2010          1324 non-null   float64
#  311 pct_Rel_Under_6_ACS_09_13         1313 non-null   float64
#  312 pct_Rel_Under_6_ACSMOE_09_13      1313 non-null   float64
#  313 pct_HHD_Moved_in_ACS_09_13        1317 non-null   float64
#  314 pct_HHD_Moved_in_ACSMOE_09_13     1317 non-null   float64
#  315 pct_PUB_ASST_INC_ACS_09_13        1317 non-null   float64
#  316 pct_PUB_ASST_INC_ACSMOE_09_13     1317 non-null   float64
#  317 avg_Agg_HH_INC_ACS_09_13          1311 non-null   object
#  318 avg_Agg_HH_INC_ACSMOE_09_13       1311 non-null   object
#  319 pct_Tot_Occp_Units_CEN_2010       1327 non-null   float64
#  320 pct_Tot_Occp_Units_ACS_09_13      1319 non-null   float64
#  321 pct_Tot_Occp_Units_ACSMOE_09_13   1319 non-null   float64
#  322 pct_Vacant_Units_CEN_2010         1327 non-null   float64
#  323 pct_Vacant_Units_ACS_09_13        1319 non-null   float64
#  324 pct_Vacant_Units_ACSMOE_09_13     1319 non-null   float64
#  325 pct_Renter_Occp_HU_CEN_2010       1327 non-null   float64
#  326 pct_Renter_Occp_HU_ACS_09_13      1317 non-null   float64
#  327 pct_Renter_Occp_HU_ACSMOE_09_13   1317 non-null   float64
#  328 pct_Owner_Occp_HU_CEN_2010        1327 non-null   float64
#  329 pct_Owner_Occp_HU_ACS_09_13       1317 non-null   float64
#  330 pct_Owner_Occp_HU_ACSMOE_09_13    1317 non-null   float64
#  331 pct_Single_Unit_ACS_09_13         1319 non-null   float64
#  332 pct_Single_Unit_ACSMOE_09_13      1319 non-null   float64
#  333 pct_MLT_U2_9_STRC_ACS_09_13       1319 non-null   float64
#  334 pct_MLT_U2_9_STRC_ACSMOE_09_13    1319 non-null   float64
#  335 pct_MLT_U10p_ACS_09_13            1319 non-null   float64
#  336 pct_MLT_U10p_ACSMOE_09_13         1319 non-null   float64
#  337 pct_Mobile_Homes_ACS_09_13        1319 non-null   float64
#  338 pct_Mobile_Homes_ACSMOE_09_13     1319 non-null   float64
#  339 pct_Crowd_Occp_U_ACS_09_13        1317 non-null   float64
#  340 pct_Crowd_Occp_U_ACSMOE_09_13     1317 non-null   float64
#  341 pct_NO_PH_SRVC_ACS_09_13          1317 non-null   float64
#  342 pct_NO_PH_SRVC_ACSMOE_09_13       1317 non-null   float64
#  343 pct_No_Plumb_ACS_09_13            1306 non-null   float64
#  344 pct_No_Plumb_ACSMOE_09_13         1306 non-null   float64
#  345 pct_Recent_Built_HU_ACS_09_13     1319 non-null   float64
#  346 pct_Recent_Built_HU_ACSMOE_09_13  1319 non-null   float64
#  347 avg_Agg_House_Value_ACS_09_13     1157 non-null   object
#  348 avg_Agg_House_Value_ACSMOE_09_13  1157 non-null   object
#  349 pct_TEA_MailOutMailBack_CEN_2010  1313 non-null   float64
#  350 pct_TEA_Update_Leave_CEN_2010     1313 non-null   float64
#  351 pct_Census_Mail_Returns_CEN_2010  1313 non-null   float64
#  352 pct_Vacant_CEN_2010               1313 non-null   float64
#  353 pct_Deletes_CEN_2010              1313 non-null   float64
#  354 pct_Census_UAA_CEN_2010           1313 non-null   float64
#  355 pct_Mailback_Count_CEN_2010       1313 non-null   float64
#  356 pct_FRST_FRMS_CEN_2010            1313 non-null   float64
#  357 pct_RPLCMNT_FRMS_CEN_2010         1313 non-null   float64
#  358 pct_BILQ_Mailout_count_CEN_2010   1313 non-null   float64
# dtypes: float64(328), int64(2), object(29)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Reformat financial data

# %%
# take a peek at the financial data stored as strings to see what kind of fromatting we're dealing with.
data_df['Aggr_House_Value_ACS_09_13'].head()
# Out:
# 0    $46,888,000
# 1    $55,911,000
# 2    $15,265,000
# 3    $80,646,000
# 4    $25,773,800
# Name: Aggr_House_Value_ACS_09_13, dtype: object

# %%
# make a list of the financial format columns
# grab all the columns with 'object' dtype
string_columns = list(data_df.select_dtypes(include=['object']).columns)
string_columns
# Out:
# ['address',
#  'city',
#  'date_added',
#  'federal_facility_ind',
#  'federal_register_url',
#  'geocode_source',
#  'site_epa_id',
#  'site_name',
#  'site_narrative_url',
#  'site_progress_url',
#  'text',
#  'State_name',
#  'County_name',
#  'Med_HHD_Inc_BG_ACS_09_13',
#  'Med_HHD_Inc_BG_ACSMOE_09_13',
#  'Med_HHD_Inc_TR_ACS_09_13',
#  'Med_HHD_Inc_TR_ACSMOE_09_13',
#  'Aggregate_HH_INC_ACS_09_13',
#  'Aggregate_HH_INC_ACSMOE_09_13',
#  'Med_House_Value_BG_ACS_09_13',
#  'Med_House_Value_BG_ACSMOE_09_13',
#  'Med_house_value_TR_ACS_09_13',
#  'Med_house_value_TR_ACSMOE_09_13',
#  'Aggr_House_Value_ACS_09_13',
#  'Aggr_House_Value_ACSMOE_09_13',
#  'avg_Agg_HH_INC_ACS_09_13',
#  'avg_Agg_HH_INC_ACSMOE_09_13',
#  'avg_Agg_House_Value_ACS_09_13',
#  'avg_Agg_House_Value_ACSMOE_09_13']

# %%
# leave off the first 13 entries ('address' ... 'County_name') since we don't need to reformat those
financial_columns = string_columns[13:]

# %%
# Loop through and reformat the columns by taking out the '$' and ',', and then changing the dtype to 'float'.
# This can take a minute or two.
for x in financial_columns:
    data_df[[x]] = (data_df[x].replace( '[\$,)]','', regex=True )
                     .replace( '[(]','-',   regex=True ).astype(float))

# %%
# Quick check to verify the format.
data_df['Aggr_House_Value_ACS_09_13'].head()
# Out:
# 0    46888000.0
# 1    55911000.0
# 2    15265000.0
# 3    80646000.0
# 4    25773800.0
# Name: Aggr_House_Value_ACS_09_13, dtype: float64

# %% [markdown]
# ### Missing GeoData
# Since we are using a map visualization, we are sensitive to missing latitude and longitude.

# %%
data_df[data_df['latitude'].isnull()]
# Out:
#       FIPS_Full                                            address  \
# 70            0                             RTE 3, JOBOS, PR 00654
# 76            0        ROAD 670 KM 3.7 PALO ALTO, MANATI, PR 00701
# 78            0  STATE ROAD #2 KM. 19.7 (ACUNA STREET), CANDELE...
# 83            0           ROAD 674, KM 2, RIO ABAJO WARD, PR 00763
# 1138          0                                                NaN
#
#                  city  date_added federal_facility_ind  \
# 70              Jobos  09/21/1984                   No
# 76             Manati  04/30/2003                   No
# 78    Candeleria Ward  02/04/2000                   No
# 83     Rio Abajo Ward  07/22/1999                   No
# 1138     Hudson River  09/21/1984                   No
#
#                                    federal_register_url geocode_source  \
# 70       https://semspub.epa.gov/src/document/11/189627            NaN
# 76    http://www.gpo.gov/fdsys/pkg/FR-2003-04-30/pdf...            NaN
# 78    http://www.gpo.gov/fdsys/pkg/FR-2000-02-04/pdf...            NaN
# 83    http://www.gpo.gov/fdsys/pkg/FR-1999-07-22/pdf...            NaN
# 1138     https://semspub.epa.gov/src/document/11/189627            NaN
#
#       latitude  longitude   site_epa_id  ... pct_TEA_MailOutMailBack_CEN_2010  \
# 70         NaN        NaN  PRD980763783  ...                              NaN
# 76         NaN        NaN  PRD987367299  ...                              NaN
# 78         NaN        NaN  PRD987376662  ...                              NaN
# 83         NaN        NaN  PRD980512669  ...                              NaN
# 1138       NaN        NaN  NYD980763841  ...                              NaN
#
#      pct_TEA_Update_Leave_CEN_2010 pct_Census_Mail_Returns_CEN_2010  \
# 70                             NaN                              NaN
# 76                             NaN                              NaN
# 78                             NaN                              NaN
# 83                             NaN                              NaN
# 1138                           NaN                              NaN
#
#       pct_Vacant_CEN_2010 pct_Deletes_CEN_2010  pct_Census_UAA_CEN_2010  \
# 70                    NaN                  NaN                      NaN
# 76                    NaN                  NaN                      NaN
# 78                    NaN                  NaN                      NaN
# 83                    NaN                  NaN                      NaN
# 1138                  NaN                  NaN                      NaN
#
#       pct_Mailback_Count_CEN_2010 pct_FRST_FRMS_CEN_2010  \
# 70                            NaN                    NaN
# 76                            NaN                    NaN
# 78                            NaN                    NaN
# 83                            NaN                    NaN
# 1138                          NaN                    NaN
#
#       pct_RPLCMNT_FRMS_CEN_2010 pct_BILQ_Mailout_count_CEN_2010
# 70                          NaN                             NaN
# 76                          NaN                             NaN
# 78                          NaN                             NaN
# 83                          NaN                             NaN
# 1138                        NaN                             NaN
#
# [5 rows x 359 columns]

# %% [markdown]
# ### Other Cleaning

# %%
# convert the column names to lowercase to avoid problems later on.
data_df.columns= data_df.columns.str.lower()

# fill in nulls with zeros
data_df.fillna(0, inplace = True)

# make sure the census block groups and tracts come through as integers rather than floats
data_df.tract = data_df.tract.astype(int)
data_df.block_group = data_df.block_group.astype(int)

# rename the 'text' column to avoid potential confusion
data_df.rename(columns={"text": "site_text"}, inplace = True)

# %% [markdown]
# ### Select Columns

# %%
# select columns we want to keep here
# for now, proof-of-concept
desired_columns = [x.lower() for x in [
                "FIPS_Block_Group",
                "address",
                "city",
                "latitude",
                "longitude",
                "site_score",
                "site_text",
                "State_name",
                "County_name",
                "Tract",
                "Block_Group",
                "Tot_Population_CEN_2010",
                "Hispanic_CEN_2010",
                "NH_Blk_alone_CEN_2010",
                "NH_AIAN_alone_CEN_2010",
                "NH_Asian_alone_CEN_2010",
                "NH_NHOPI_alone_CEN_2010",
                "NH_SOR_alone_CEN_2010",
                "College_ACS_09_13",
                "No_Health_Ins_ACS_09_13",
                "Med_HHD_Inc_BG_ACS_09_13",
                "Aggregate_HH_INC_ACS_09_13",
                "Tot_Vacant_Units_CEN_2010",
                "Renter_Occp_HU_CEN_2010",
                "Owner_Occp_HU_CEN_2010",
                "No_Plumb_ACS_09_13",
                "Med_House_Value_BG_ACS_09_13",
                "pct_Hispanic_CEN_2010",
                "pct_NH_Blk_alone_CEN_2010",
                "pct_NH_AIAN_alone_CEN_2010",
                "pct_NH_Asian_alone_CEN_2010",
                "pct_NH_NHOPI_alone_CEN_2010",
                "pct_NH_SOR_alone_CEN_2010",
                "pct_Not_HS_Grad_ACS_09_13",
                "pct_No_Health_Ins_ACS_09_13",
                "pct_Vacant_Units_CEN_2010",
                "pct_Renter_Occp_HU_CEN_2010",
                "pct_Owner_Occp_HU_CEN_2010",
                "pct_No_Plumb_ACS_09_13"]]
cleaned_data_df = data_df[desired_columns]

# %%
# last check
cleaned_data_df.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1344 entries, 0 to 1343
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   fips_block_group              1344 non-null   int64
#  1   address                       1344 non-null   object
#  2   city                          1344 non-null   object
#  3   latitude                      1344 non-null   float64
#  4   longitude                     1344 non-null   float64
#  5   site_score                    1344 non-null   float64
#  6   site_text                     1344 non-null   object
#  7   state_name                    1344 non-null   object
#  8   county_name                   1344 non-null   object
#  9   tract                         1344 non-null   int32
#  10  block_group                   1344 non-null   int32
#  11  tot_population_cen_2010       1344 non-null   float64
#  12  hispanic_cen_2010             1344 non-null   float64
#  13  nh_blk_alone_cen_2010         1344 non-null   float64
#  14  nh_aian_alone_cen_2010        1344 non-null   float64
#  15  nh_asian_alone_cen_2010       1344 non-null   float64
#  16  nh_nhopi_alone_cen_2010       1344 non-null   float64
#  17  nh_sor_alone_cen_2010         1344 non-null   float64
#  18  college_acs_09_13             1344 non-null   float64
#  19  no_health_ins_acs_09_13       1344 non-null   float64
#  20  med_hhd_inc_bg_acs_09_13      1344 non-null   float64
#  21  aggregate_hh_inc_acs_09_13    1344 non-null   float64
#  22  tot_vacant_units_cen_2010     1344 non-null   float64
#  23  renter_occp_hu_cen_2010       1344 non-null   float64
#  24  owner_occp_hu_cen_2010        1344 non-null   float64
#  25  no_plumb_acs_09_13            1344 non-null   float64
#  26  med_house_value_bg_acs_09_13  1344 non-null   float64
#  27  pct_hispanic_cen_2010         1344 non-null   float64
#  28  pct_nh_blk_alone_cen_2010     1344 non-null   float64
#  29  pct_nh_aian_alone_cen_2010    1344 non-null   float64
#  30  pct_nh_asian_alone_cen_2010   1344 non-null   float64
#  31  pct_nh_nhopi_alone_cen_2010   1344 non-null   float64
#  32  pct_nh_sor_alone_cen_2010     1344 non-null   float64
#  33  pct_not_hs_grad_acs_09_13     1344 non-null   float64
#  34  pct_no_health_ins_acs_09_13   1344 non-null   float64
#  35  pct_vacant_units_cen_2010     1344 non-null   float64
#  36  pct_renter_occp_hu_cen_2010   1344 non-null   float64
#  37  pct_owner_occp_hu_cen_2010    1344 non-null   float64
#  38  pct_no_plumb_acs_09_13        1344 non-null   float64
# dtypes: float64(31), int32(2), int64(1), object(5)
# memory usage: 409.5+ KB

# %% [markdown]
# ## Export

# %%
# Export to csv
cleaned_data_df.to_csv(cleaned_data_csv, index = False)

# %%
# Export to flat json
cleaned_data_df.to_json(cleaned_data_json, orient='records')
