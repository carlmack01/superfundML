# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_merged_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    fips_block_group state_name     county_name    tract  block_group  \
# 0       10010201001    Alabama  Autauga County  20100.0          1.0
# 1       10010201002    Alabama  Autauga County  20100.0          2.0
# 2       10010202001    Alabama  Autauga County  20200.0          1.0
# 3       10010202002    Alabama  Autauga County  20200.0          2.0
# 4       10010203001    Alabama  Autauga County  20300.0          1.0
#
#    tot_population_cen_2010  hispanic_cen_2010  nh_blk_alone_cen_2010  \
# 0                    698.0               18.0                   78.0
# 1                   1214.0               26.0                  139.0
# 2                   1003.0               31.0                  625.0
# 3                   1167.0               44.0                  589.0
# 4                   2549.0               69.0                  477.0
#
#    nh_aian_alone_cen_2010  nh_asian_alone_cen_2010  ...  \
# 0                     5.0                      3.0  ...
# 1                     8.0                     11.0  ...
# 2                     4.0                      4.0  ...
# 3                     1.0                      1.0  ...
# 4                     7.0                      9.0  ...
#
#    pct_renter_occp_hu_cen_2010  pct_owner_occp_hu_cen_2010  \
# 0                        31.68                       68.32
# 1                        17.17                       82.83
# 2                        35.48                       64.52
# 3                        38.06                       61.94
# 4                        16.94                       83.06
#
#    pct_no_plumb_acs_09_13  has_superfund  address  city  latitude  longitude  \
# 0                    6.80            0.0        0     0       0.0        0.0
# 1                   12.44            0.0        0     0       0.0        0.0
# 2                    4.57            0.0        0     0       0.0        0.0
# 3                    6.64            0.0        0     0       0.0        0.0
# 4                    2.10            0.0        0     0       0.0        0.0
#
#    site_score  site_text
# 0         0.0          0
# 1         0.0          0
# 2         0.0          0
# 3         0.0          0
# 4         0.0          0
#
# [5 rows x 40 columns]

# %%
df= df[df['has_superfund'] != 0]
df.head()
# Out:
#       fips_block_group state_name       county_name    tract  block_group  \
# 264        10150015003    Alabama    Calhoun County   1500.0          3.0
# 1070       10670305003    Alabama      Henry County  30500.0          3.0
# 1458       10730110012    Alabama  Jefferson County  11001.0          2.0
# 2158       10890111001    Alabama    Madison County  11100.0          1.0
# 2159       10890111001    Alabama    Madison County  11100.0          1.0
#
#       tot_population_cen_2010  hispanic_cen_2010  nh_blk_alone_cen_2010  \
# 264                    1247.0               14.0                   29.0
# 1070                   2227.0               25.0                  501.0
# 1458                    882.0               52.0                   56.0
# 2158                   1955.0              210.0                  377.0
# 2159                   1955.0              210.0                  377.0
#
#       nh_aian_alone_cen_2010  nh_asian_alone_cen_2010  ...  \
# 264                     12.0                      3.0  ...
# 1070                     9.0                      7.0  ...
# 1458                     2.0                      5.0  ...
# 2158                    20.0                     33.0  ...
# 2159                    20.0                     33.0  ...
#
#       pct_renter_occp_hu_cen_2010  pct_owner_occp_hu_cen_2010  \
# 264                         21.00                       79.00
# 1070                        37.45                       62.55
# 1458                        26.56                       73.44
# 2158                        97.99                        2.01
# 2159                        97.99                        2.01
#
#       pct_no_plumb_acs_09_13  has_superfund  \
# 264                     0.00            1.0
# 1070                    3.95            1.0
# 1458                    0.00            1.0
# 2158                    0.96            1.0
# 2159                    0.96            1.0
#
#                                                 address               city  \
# 264                  OFF AL HWY 202, ANNISTON, AL 36253           Anniston
# 1070               HIGHWAY 134 WEST, HEADLAND, AL 36345           Headland
# 1458                1247 BORDEN AVE SE, LEEDS, AL 35094              Leeds
# 2158      USAMICOM DRSMI KL, LIMESTONE/MORGAN, AL 35898  Limestone, Morgan
# 2159  Postal Address is unavailable for the Site, HU...         Huntsville
#
#        latitude  longitude  site_score  \
# 264   33.623214 -85.923679       51.91
# 1070  31.351466 -85.342147       55.61
# 1458  33.538652 -86.533784       42.86
# 2158  34.630000 -86.650000       61.42
# 2159  34.672990 -86.651033       50.00
#
#                                               site_text
# 264   NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 1070  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 1458  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 2158  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 2159  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
#
# [5 rows x 40 columns]

# %%
selected_features = df.loc[:, df.columns != 'site_score']
selected_features.head()
# Out:
#       fips_block_group state_name       county_name    tract  block_group  \
# 264        10150015003    Alabama    Calhoun County   1500.0          3.0
# 1070       10670305003    Alabama      Henry County  30500.0          3.0
# 1458       10730110012    Alabama  Jefferson County  11001.0          2.0
# 2158       10890111001    Alabama    Madison County  11100.0          1.0
# 2159       10890111001    Alabama    Madison County  11100.0          1.0
#
#       tot_population_cen_2010  hispanic_cen_2010  nh_blk_alone_cen_2010  \
# 264                    1247.0               14.0                   29.0
# 1070                   2227.0               25.0                  501.0
# 1458                    882.0               52.0                   56.0
# 2158                   1955.0              210.0                  377.0
# 2159                   1955.0              210.0                  377.0
#
#       nh_aian_alone_cen_2010  nh_asian_alone_cen_2010  ...  \
# 264                     12.0                      3.0  ...
# 1070                     9.0                      7.0  ...
# 1458                     2.0                      5.0  ...
# 2158                    20.0                     33.0  ...
# 2159                    20.0                     33.0  ...
#
#       pct_vacant_units_cen_2010  pct_renter_occp_hu_cen_2010  \
# 264                        9.75                        21.00
# 1070                       9.11                        37.45
# 1458                      12.97                        26.56
# 2158                       9.38                        97.99
# 2159                       9.38                        97.99
#
#       pct_owner_occp_hu_cen_2010  pct_no_plumb_acs_09_13  has_superfund  \
# 264                        79.00                    0.00            1.0
# 1070                       62.55                    3.95            1.0
# 1458                       73.44                    0.00            1.0
# 2158                        2.01                    0.96            1.0
# 2159                        2.01                    0.96            1.0
#
#                                                 address               city  \
# 264                  OFF AL HWY 202, ANNISTON, AL 36253           Anniston
# 1070               HIGHWAY 134 WEST, HEADLAND, AL 36345           Headland
# 1458                1247 BORDEN AVE SE, LEEDS, AL 35094              Leeds
# 2158      USAMICOM DRSMI KL, LIMESTONE/MORGAN, AL 35898  Limestone, Morgan
# 2159  Postal Address is unavailable for the Site, HU...         Huntsville
#
#        latitude  longitude                                          site_text
# 264   33.623214 -85.923679  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 1070  31.351466 -85.342147  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 1458  33.538652 -86.533784  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 2158  34.630000 -86.650000  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
# 2159  34.672990 -86.651033  NPL SITE LISTING NARRATIVE\n\n\nNPL Site Narra...
#
# [5 rows x 39 columns]

# %%
selected_features = selected_features.loc[:, selected_features.columns != 'latitude']

# %%
selected_features = selected_features.loc[:, selected_features.columns != 'longitude']

# %%
selected_features = selected_features.loc[:, selected_features.columns != 'fips_full']

# %%
selected_features = selected_features.loc[:, selected_features.columns != 'has_superfund']

# %%
selected_features = selected_features.loc[:, selected_features.columns != 'fips_block_group']

# %%
cols_to_remove = []

for col in selected_features.columns:
    try:
        _ = selected_features[col].astype(float)
    except ValueError:
        print('Couldn\'t covert %s to float' % col)
        cols_to_remove.append(col)
        pass

# keep only the columns in df that do not contain string
selected_features = selected_features[[col for col in selected_features.columns if col not in cols_to_remove]]
# Out:
# Couldn't covert state_name to float
# Couldn't covert county_name to float
# Couldn't covert address to float
# Couldn't covert city to float
# Couldn't covert site_text to float

# %%
X = selected_features
y = df[['site_score']]
X.shape, y.shape
# Out:
# ((1340, 30), (1340, 1))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.03519787131595209
# Testing Score: -0.03341187091681741

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
coef = model.coef_[0]
col_names = X.columns
feat_lst = list(zip(col_names, coef))
summary_df = pd.DataFrame({'feature_name': col_names, 'correl': coef})
summary_df.sort_values(['correl'], ascending=False)
# Out:
#                     feature_name        correl
# 8          nh_sor_alone_cen_2010  1.384358e-01
# 20    pct_nh_aian_alone_cen_2010  1.175809e-01
# 26     pct_vacant_units_cen_2010  7.809040e-02
# 29        pct_no_plumb_acs_09_13  7.231040e-02
# 18         pct_hispanic_cen_2010  7.104042e-02
# 1                    block_group  6.286442e-02
# 22   pct_nh_nhopi_alone_cen_2010  4.432337e-02
# 25   pct_no_health_ins_acs_09_13  3.780377e-02
# 19     pct_nh_blk_alone_cen_2010  3.657338e-02
# 7        nh_nhopi_alone_cen_2010  1.833127e-02
# 28    pct_owner_occp_hu_cen_2010  4.075641e-03
# 10       no_health_ins_acs_09_13  3.178325e-03
# 15        owner_occp_hu_cen_2010  2.093052e-03
# 6        nh_asian_alone_cen_2010  1.967147e-03
# 14       renter_occp_hu_cen_2010  1.752920e-03
# 2        tot_population_cen_2010  3.659040e-04
# 11      med_hhd_inc_bg_acs_09_13  4.172591e-06
# 17  med_house_value_bg_acs_09_13  1.819082e-06
# 0                          tract  1.511388e-06
# 12    aggregate_hh_inc_acs_09_13  3.230285e-08
# 4          nh_blk_alone_cen_2010 -1.092356e-03
# 16            no_plumb_acs_09_13 -2.303354e-03
# 3              hispanic_cen_2010 -3.282565e-03
# 13     tot_vacant_units_cen_2010 -3.802465e-03
# 9              college_acs_09_13 -8.124968e-03
# 5         nh_aian_alone_cen_2010 -8.302277e-03
# 27   pct_renter_occp_hu_cen_2010 -8.360787e-03
# 21   pct_nh_asian_alone_cen_2010 -1.455223e-02
# 24     pct_not_hs_grad_acs_09_13 -1.189075e-01
# 23     pct_nh_sor_alone_cen_2010 -3.976585e+00

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             site_score   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.117
# Date:                Thu, 08 Oct 2020   Prob (F-statistic):              0.304
# Time:                        19:33:18   Log-Likelihood:                -5188.1
# No. Observations:                1340   AIC:                         1.044e+04
# Df Residuals:                    1309   BIC:                         1.060e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           42.0840      3.689     11.407      0.000      34.847      49.321
# tract                         1.008e-06   9.12e-07      1.105      0.270   -7.82e-07     2.8e-06
# block_group                     -0.1516      0.286     -0.529      0.597      -0.713       0.410
# tot_population_cen_2010          0.0004      0.001      0.467      0.641      -0.001       0.002
# hispanic_cen_2010               -0.0040      0.002     -1.855      0.064      -0.008       0.000
# nh_blk_alone_cen_2010           -0.0017      0.002     -0.685      0.494      -0.007       0.003
# nh_aian_alone_cen_2010          -0.0058      0.015     -0.397      0.691      -0.034       0.023
# nh_asian_alone_cen_2010         -0.0012      0.005     -0.237      0.813      -0.011       0.009
# nh_nhopi_alone_cen_2010          0.0109      0.091      0.119      0.905      -0.168       0.189
# nh_sor_alone_cen_2010            0.1384      0.088      1.571      0.116      -0.034       0.311
# college_acs_09_13               -0.0047      0.003     -1.351      0.177      -0.011       0.002
# no_health_ins_acs_09_13          0.0057      0.004      1.625      0.105      -0.001       0.013
# med_hhd_inc_bg_acs_09_13      -2.63e-07   2.28e-05     -0.012      0.991   -4.51e-05    4.45e-05
# aggregate_hh_inc_acs_09_13      2.9e-08   3.68e-08      0.789      0.430   -4.31e-08    1.01e-07
# tot_vacant_units_cen_2010       -0.0020      0.008     -0.251      0.802      -0.017       0.013
# renter_occp_hu_cen_2010          0.0004      0.004      0.106      0.916      -0.007       0.008
# owner_occp_hu_cen_2010          -0.0006      0.004     -0.155      0.877      -0.008       0.007
# no_plumb_acs_09_13              -0.0090      0.021     -0.434      0.665      -0.050       0.032
# med_house_value_bg_acs_09_13  -8.26e-07   3.47e-06     -0.238      0.812   -7.64e-06    5.99e-06
# pct_hispanic_cen_2010            0.0778      0.040      1.937      0.053      -0.001       0.156
# pct_nh_blk_alone_cen_2010        0.0160      0.038      0.426      0.670      -0.058       0.090
# pct_nh_aian_alone_cen_2010       0.1231      0.184      0.669      0.503      -0.238       0.484
# pct_nh_asian_alone_cen_2010      0.0068      0.092      0.074      0.941      -0.173       0.187
# pct_nh_nhopi_alone_cen_2010      0.2741      1.436      0.191      0.849      -2.542       3.091
# pct_nh_sor_alone_cen_2010       -3.6185      1.079     -3.354      0.001      -5.735      -1.502
# pct_not_hs_grad_acs_09_13       -0.0909      0.041     -2.206      0.028      -0.172      -0.010
# pct_no_health_ins_acs_09_13     -0.0499      0.060     -0.826      0.409      -0.168       0.069
# pct_vacant_units_cen_2010        0.0691      0.065      1.071      0.284      -0.057       0.196
# pct_renter_occp_hu_cen_2010      0.0059      0.043      0.137      0.891      -0.079       0.090
# pct_owner_occp_hu_cen_2010       0.0115      0.042      0.271      0.786      -0.072       0.095
# pct_no_plumb_acs_09_13           0.0647      0.109      0.594      0.553      -0.149       0.278
# ==============================================================================
# Omnibus:                      197.754   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              600.150
# Skew:                          -0.744   Prob(JB):                    4.78e-131
# Kurtosis:                       5.922   Cond. No.                     6.03e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.03e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X = X.loc[:, ['hispanic_cen_2010', 'pct_hispanic_cen_2010', 'pct_nh_sor_alone_cen_2010', 'pct_not_hs_grad_acs_09_13', 'pct_not_hs_grad_acs_09_13' ]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.014944568926780645
# Testing Score: -0.0030686119954774767

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
coef = model.coef_[0]
col_names = X.columns
feat_lst = list(zip(col_names, coef))
summary_df = pd.DataFrame({'feature_name': col_names, 'correl': coef})
summary_df.sort_values(['correl'], ascending=False)
# Out:
#                 feature_name    correl
# 1      pct_hispanic_cen_2010  0.026628
# 0          hispanic_cen_2010 -0.000918
# 4  pct_not_hs_grad_acs_09_13 -0.022431
# 3  pct_not_hs_grad_acs_09_13 -0.022431
# 2  pct_nh_sor_alone_cen_2010 -2.817810

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             site_score   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     3.730
# Date:                Thu, 08 Oct 2020   Prob (F-statistic):            0.00503
# Time:                        19:52:13   Log-Likelihood:                -5197.6
# No. Observations:                1340   AIC:                         1.041e+04
# Df Residuals:                    1335   BIC:                         1.043e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        43.9247      0.514     85.390      0.000      42.916      44.934
# hispanic_cen_2010            -0.0014      0.001     -1.297      0.195      -0.003       0.001
# pct_hispanic_cen_2010         0.0393      0.027      1.450      0.147      -0.014       0.092
# pct_nh_sor_alone_cen_2010    -2.2976      0.686     -3.348      0.001      -3.644      -0.951
# pct_not_hs_grad_acs_09_13    -0.0275      0.016     -1.721      0.085      -0.059       0.004
# pct_not_hs_grad_acs_09_13    -0.0275      0.016     -1.721      0.085      -0.059       0.004
# ==============================================================================
# Omnibus:                      208.916   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              629.962
# Skew:                          -0.786   Prob(JB):                    1.61e-137
# Kurtosis:                       5.968   Cond. No.                     7.64e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.62e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
